# %%
#1. What does RGBA stand for?

"""RGBA stand for red, green, and blue alpha. While it is sometimes described as a 
   color space, it is actually a three-channel RGB color model supplemented with
   a fourth alpha channel. Alpha indicates how opaque each pixel is and allows
   an image to be combined over others using alpha compositing,with transparaent
   areas and anti-aliasing of the edges of opaque regions."""

#2. From the Pillow module, how do you get the RGBA value of any images?

"""To create a transparent png using Python3, the pillow library is used.
   The pillow library comes with python itself. If python is unable to
   find Pillow library then open the commang promot and run this command."""

#3. What is a box tuple, and how does it work?

"""The box tuple a submodule provides read-only access for the tuple userdata type.
   It allows, for a single tuple:selective retrievel of the field contents, retrieval
   of information about size, iteration over all the fields, and conversion to a Lua table."""

#4. Use your image and load in notebook then, How can you find out the width and height of an
Image object?

"""In this articale, we are going to discuss how to get the height and width of a particular image.
   In order to find the height and width of an image, there are two approaches. The first approach
   is by using the PIL(Pillow) library and the second approach is by using the Open-CV library
   
   PIL is the Python Imaging Library is an important module which is used for image processing.
   It supports many formates of image such as "jpeg", "png", "ppm," "tiff", "bmp", "gif".
   It provides many image editing capabilities. The same name which is used to represent a
   PIL image."""

#5. What method would you call to get Image object for a 100×100 image, excluding the lower-left
quarter of it?

"""A digital image is nothing more than data- numbers indicating variations of red, 
   green, and blue at a particular location on a grid of pixel. Most of the time, 
   we view these pixels as miniature rectangle sandwiched together on a computer screen.
   With a tittle creative thinking and some lower level manupulation of pixels with
   code, however, we can display that information in myriad of ways. This tutorial
   is dedicated to breaking out of simple shape drawing in processing and using image
   (and their pixel) as the building blocks of processing graphics."""

#6. After making changes to an Image object, how could you save it as an image file?

"""Saves this image under the given filename. If no format is specified, the
   formate to use is determined from the filename extension, if possible.
   
   Keyword option can be used to provide additional instructions to thr writer.
   If a writer dosen't recognise an option, it is silently ignored. The 
   available options are desribed in the image formate documentation for each writer."""

#7. What module contains Pillow’s shape-drawing code?

"""Pillow prvides a drawing module called ImageDraw that you can use to create simple 2D
   graphics on your Image object. According to Pillow's documentation,"you can use this module
   to create new image, annotate or retouch exisiting image, and to generate graphics on the 
   fly for web use."
   
   If you need more advanced drawing capabilities that what is included in Pillow,
   you can get a seprate package called aggdraw."""

#8. Image objects do not have drawing methods. What kind of object does? How do you get this kind
of object?

"""An Object is an instance of a class. A class is like a blueprint while an instance
   is a copy of the class with actual values. Python is object-oriented programming
   language that stresses on object i.e. it mainly emphasizes fuction. Objects
   i.e. it mainly emphasize fuctions. Ojects are basically an encapsulation
   of data variables and methdes acting in that data into a single entity.
   
   You will see the term "object" be used frequently throughtly this . In Python,
   the term "object" is quite the catch-all; including numbers, strings of characters,
   lits, fuctions-a Python object is essentially anything that you can assign to a variable.
   That being said, there are different types of object: Python treats integers as a
   different type of object than string, for instance. """
